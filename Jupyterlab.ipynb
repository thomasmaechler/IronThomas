# %% [markdown]
# # My holidays preference

# %% [markdown]
# ### Table of Contents
#
# * [Why this notebook](#chapter1)
# * [Question on your name](#chapter2)
# * [Picture of me](#chapter3)
# * [My holidays preferences](#chapter4)
# * [Localisation of my favorit holidays](#chapter5)
# * [My favorit activities](#chapter6)
# * [A link to discover this amazing place](#chapter7)

# %% [markdown]
# ### Why this notebook <a class="anchor" id="chapter1"></a>

# %% [markdown]
# In the __notebook__ that i created, i'm introducing my  <span style="color:red">_holidays_</span> preference with a <span style="color:orange">__picture__</span> and a link to a youtube video of my <span style="color:blue">_holidays_</span> preference

# %% [markdown]
# ### Question on your name <a class="anchor" id="chapter2"></a>

# %%
name=input("what's your name: ")

# %% [markdown]
# <span style="color:blue">_"For this part i just used the simple formula "input" to ask the age of the person"_</span>

# %% [markdown]
# ### Picture of me <a class="anchor" id="chapter3"></a>

# %% [markdown]
# ![Screenshot%202021-02-14%20at%2023.23.20.png](attachment:Screenshot%202021-02-14%20at%2023.23.20.png)

# %% [markdown]
# <span style="color:blue">_"To upload the picture, i just put a markdown cell and import the picture directly from my laptop"_</span>

# %% [markdown]
# ### My holidays preferences <a class="anchor" id="chapter4"></a>

# %%
holidayslocation=input("what's your favorite location: ")
typeofholidays=input("what's your favorite type of holidays: ")

# %% [markdown]
# <span style="color:blue">_"For asking 2 question, i just putted 2 "input" formula"_</span>

# %% [markdown]
# ### Localisation of my favorit holidays <a class="anchor" id="chapter5"></a>

# %% [markdown]
# ![map-village-cap-ferret-768x703.jpeg](attachment:map-village-cap-ferret-768x703.jpeg)

# %% [markdown]
# <span style="color:blue">_"To upload the picture, i just put a markdown cell and import the picture directly from my laptop"_</span>

# %% [markdown]
# ### My favorit activities <a class="anchor" id="chapter6"></a>

# %% [markdown]
# The type of __activites__ i prefer the most to do during this _holidays_ are:
# - <span style="color:red">Surfing</span>
# - <span style="color:orange">Chilling with my friends and familly</span>
# - <span style="color:yellow">Eating good sea food</span>

# %% [markdown]
# <span style="color:blue">_"To put the text in color, i found a formula in google with the span and the color, quite easy to use"_</span>

# %% [markdown]
# ### A link to discover this amazing place <a class="anchor" id="chapter7"></a>

# %% [markdown]
# [Youtube vidéo of the Cap ferret](https://www.youtube.com/watch?v=dvvTKuOSFYQ)

# %% [markdown]
# <span style="color:blue">_"To put the Youtube link, i just used what we have learn in the prework"_</span>
